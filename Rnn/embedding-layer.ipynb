# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, Dense , Input
from keras.preprocessing.sequence import pad_sequences
import tensorflow as tf

# %%
docs = [
    "Hi my name is python",
    "Yo gang wassup",
    "I am learning RNN",
    "six seven eight nine ten",
    "India winner Paxtan looser",
    "Tonight is a good night",
    "I love India",
    "Wow what a scene"
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 

tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[5, 6, 7, 1, 8],
#  [9, 10, 11],
#  [2, 12, 13, 14],
#  [15, 16, 17, 18, 19],
#  [3, 20, 21, 22],
#  [23, 1, 4, 24, 25],
#  [2, 26, 3],
#  [27, 28, 4, 29]]

# %%
from keras.utils import pad_sequences

sequences = pad_sequences(sequences , padding='post')
sequences
# Out:
# array([[ 5,  6,  7,  1,  8],
#        [ 9, 10, 11,  0,  0],
#        [ 2, 12, 13, 14,  0],
#        [15, 16, 17, 18, 19],
#        [ 3, 20, 21, 22,  0],
#        [23,  1,  4, 24, 25],
#        [ 2, 26,  3,  0,  0],
#        [27, 28,  4, 29,  0]], dtype=int32)

# %%
from tensorflow.keras.layers import Embedding

model = Sequential([
    Input(shape=(5,)),
    Embedding(30, output_dim=5)
])

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 5, 5)           │           150 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 150 (600.00 B)
#  Trainable params: 150 (600.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile("adam", "accuracy")

# %%
pred = model.predict(sequences)
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# array([[[-4.6718050e-02, -2.5067925e-02,  3.1805858e-03,  6.6475756e-03,
#          -5.8121681e-03],
#         [-2.2324432e-02,  4.6206359e-02, -2.2547293e-02, -3.7457250e-02,
#           3.2449793e-02],
#         [ 4.1305456e-02,  9.9287406e-03,  6.6133626e-03,  4.1061286e-02,
#          -1.0930289e-02],
#         [-3.2066382e-02,  3.9024893e-02,  1.5946854e-02,  4.7857650e-03,
#           3.0193578e-02],
#         [-7.1680769e-03,  3.6337201e-02,  3.8964439e-02,  1.1149682e-02,
#           2.6216533e-02]],
#
#        [[-2.3637617e-02, -4.9825728e-02, -4.6060633e-02, -9.7235925e-03,
#          -2.1892078e-03],
#         [-5.3880215e-03, -4.8812255e-03, -1.6034104e-02, -3.0646576e-02,
#           1.3919361e-03],
#         [ 4.7771659e-02, -3.9460622e-02,  2.8095674e-02,  2.0626139e-02,
#           3.6175735e-03],
#         [ 3.9219484e-03,  4.3693427e-02, -3.5103716e-02,  4.4362340e-02,
#          -1.5609574e-02],
#         [ 3.9219484e-03,  4.3693427e-02, -3.5103716e-02,  4.4362340e-02,
#          -1.5609574e-02]],
#
#        [[ 3.2587051e-03, -2.9553866e-02,  4.9103621e-02, -6.3246265e-03,
#          -1.2861263e-02],
#         [-3.1889461e-02,  3.4370814e-02,  3.2957915e-02,  2.4886701e-02,
#           5.7914034e-03],
#         [-4.5014810e-02, -2.5166964e-02,  5.3084381e-03,  9.3497336e-05,
#           1.5142653e-02],
#         [ 1.9538786e-02,  3.8252585e-03, -3.4981679e-02,  1.4247742e-02,
#          -1.7697774e-02],
#         [ 3.9219484e-03,  4.3693427e-02, -3.5103716e-02,  4.4362340e-02,
#          -1.5609574e-02]],
#
