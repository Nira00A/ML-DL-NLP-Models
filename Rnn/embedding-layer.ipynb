# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, Dense , Input
from keras.preprocessing.sequence import pad_sequences
import tensorflow as tf

# %%
docs = [
    "Hi my name is python",
    "Yo gang wassup",
    "I am learning RNN",
    "six seven eight nine ten",
    "India winner Paxtan looser",
    "Tonight is a good night",
    "I love India",
    "Wow what a scene"
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 

tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[5, 6, 7, 1, 8],
#  [9, 10, 11],
#  [2, 12, 13, 14],
#  [15, 16, 17, 18, 19],
#  [3, 20, 21, 22],
#  [23, 1, 4, 24, 25],
#  [2, 26, 3],
#  [27, 28, 4, 29]]

# %%
from keras.utils import pad_sequences

sequences = pad_sequences(sequences , padding='post')
sequences
# Out:
# array([[ 5,  6,  7,  1,  8],
#        [ 9, 10, 11,  0,  0],
#        [ 2, 12, 13, 14,  0],
#        [15, 16, 17, 18, 19],
#        [ 3, 20, 21, 22,  0],
#        [23,  1,  4, 24, 25],
#        [ 2, 26,  3,  0,  0],
#        [27, 28,  4, 29,  0]], dtype=int32)

# %%
from tensorflow.keras.layers import Embedding

model = Sequential([
    Input(shape=(8,5)),
    Embedding(29, output_dim=8, input_length=5)
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 8, 5, 8)        │           232 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 232 (928.00 B)
#  Trainable params: 232 (928.00 B)
#  Non-trainable params: 0 (0.00 B)
